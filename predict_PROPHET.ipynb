# %%
from models import get_prophet_predictions_dataframe

# %%
model_path = "models/final/20210609084908_prophet_std.json"
data = get_prophet_predictions_dataframe(model_path, periods=48, results_to_file=True)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
data
# Out:
#                      predictions
# 2019-10-01 00:00:00    12.420581
# 2019-10-01 01:00:00     6.748010
# 2019-10-01 02:00:00     3.686457
# 2019-10-01 03:00:00     8.589369
# 2019-10-01 04:00:00    26.096448
# 2019-10-01 05:00:00    53.639091
# 2019-10-01 06:00:00    80.607724
# 2019-10-01 07:00:00    95.098261
# 2019-10-01 08:00:00    92.741412
# 2019-10-01 09:00:00    79.698080
# 2019-10-01 10:00:00    67.058729
# 2019-10-01 11:00:00    61.772939
# 2019-10-01 12:00:00    62.272865
# 2019-10-01 13:00:00    62.249704
# 2019-10-01 14:00:00    58.230960
# 2019-10-01 15:00:00    53.275661
# 2019-10-01 16:00:00    53.342992
# 2019-10-01 17:00:00    60.330736
# 2019-10-01 18:00:00    69.021151
# 2019-10-01 19:00:00    71.125834
# 2019-10-01 20:00:00    62.484636
# 2019-10-01 21:00:00    46.423606
# 2019-10-01 22:00:00    30.264326
# 2019-10-01 23:00:00    18.844148
# 2019-10-02 00:00:00    11.667277
# 2019-10-02 01:00:00     6.231053
# 2019-10-02 02:00:00     3.426736
# ...
